# %%
# pandas creating and reading csv files
import pandas as  pd

data=pd.DataFrame({'name':['tom','mark','tony','mark'],
                   'age':[23,36,37,25],
                    'university':['JNU','BHU','DU','SPPU']})
data
# Out:
#    name  age university
# 0   tom   23        JNU
# 1  mark   36        BHU
# 2  tony   37         DU
# 3  mark   25       SPPU

# %%
data.to_csv('student.csv')

# %%
new_data=pd.read_csv('C:\\Users\\Admin\\student.csv')

# %%
new_data
# Out:
#     name  age university
# 0    tom   32        BHU
# 1  rocky   26        JNU
# 2   mike   23         DU
# 3    raj   25       SPPU

# %%
#uploading datasets
sam=pd.read_csv("C:\\Users\\Admin\\movies.csv")

# %%
sam
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
sam.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
sam.groupby('title')[['movieId']].count()
# Out:
#                                            movieId
# title
# "Great Performances" Cats (1998)                 1
# $9.99 (2008)                                     1
# 'Hellboy': The Seeds of Creation (2004)          1
# 'Neath the Arizona Skies (1934)                  1
# 'Round Midnight (1986)                           1
# ...                                            ...
# xXx (2002)                                       1
# xXx: State of the Union (2005)                   1
# ¡Three Amigos! (1986)                            1
# À nous la liberté (Freedom for Us) (1931)        1
# İtirazım Var (2014)                              1
#
# [9123 rows x 1 columns]

# %%
sam.groupby(['title','genres'])[['movieId']].count()
# Out:
#                                                                                        movieId
# title                                     genres
# "Great Performances" Cats (1998)          Musical                                            1
# $9.99 (2008)                              Animation                                          1
# 'Hellboy': The Seeds of Creation (2004)   Action|Adventure|Comedy|Documentary|Fantasy        1
# 'Neath the Arizona Skies (1934)           Western                                            1
# 'Round Midnight (1986)                    Drama|Musical                                      1
# ...                                                                                        ...
# xXx (2002)                                Action|Crime|Thriller                              1
# xXx: State of the Union (2005)            Action|Crime|Thriller                              1
# ...

# %%
# pandas date range
# year-month-day day ferquency
pd.date_range(start='2024-04-02',end='2024-04-08')
# Out:
# DatetimeIndex(['2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05',
#                '2024-04-06', '2024-04-07', '2024-04-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
#month frequency
pd.date_range(start='2024-04-02',end='2024-08-02', freq='M')
# Out:
# DatetimeIndex(['2024-04-30', '2024-05-31', '2024-06-30', '2024-07-31'], dtype='datetime64[ns]', freq='M')

# %%
#weekdays frequency
pd.date_range(start='2024-04-02',end='2024-04-12', freq='B')
# Out:
# DatetimeIndex(['2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05',
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12'],
#               dtype='datetime64[ns]', freq='B')

# %%
data
# Out:
#    name  age university
# 0   tom   23        JNU
# 1  mark   36        BHU
# 2  tony   37         DU
# 3  mark   25       SPPU

# %%
data['city']=['Delhi','Mumbai','Pune','Satara']
data
# Out:
#    name  age university    city
# 0   tom   23        JNU   Delhi
# 1  mark   36        BHU  Mumbai
# 2  tony   37         DU    Pune
# 3  mark   25       SPPU  Satara

# %%
data.columns=['NAME','AGE','UNIVERSITY','CITY']
data.head()
# Out:
#    NAME  AGE UNIVERSITY    CITY
# 0   tom   23        JNU   Delhi
# 1  mark   36        BHU  Mumbai
# 2  tony   37         DU    Pune
# 3  mark   25       SPPU  Satara

# %%
data.drop(['AGE'],axis=1)
data
# Out:
#    NAME  AGE UNIVERSITY    CITY
# 0   tom   23        JNU   Delhi
# 1  mark   36        BHU  Mumbai
# 2  tony   37         DU    Pune
# 3  mark   25       SPPU  Satara

# %%
data.drop(['AGE'],axis=1,inplace=True)
data
# Out:
#    NAME UNIVERSITY    CITY
# 0   tom        JNU   Delhi
# 1  mark        BHU  Mumbai
# 2  tony         DU    Pune
# 3  mark       SPPU  Satara

# %%
# creating marks column
data['MARKS']=[210,234,226,230]

# %%
#apply method
data['MARKS']=data['MARKS'].apply(lambda x:x/5)
data
# Out:
#    NAME UNIVERSITY    CITY  MARKS
# 0   tom        JNU   Delhi   42.0
# 1  mark        BHU  Mumbai   46.8
# 2  tony         DU    Pune   45.2
# 3  mark       SPPU  Satara   46.0

# %%
data.sort_index(ascending=False)
# Out:
#    NAME UNIVERSITY    CITY  MARKS
# 3  mark       SPPU  Satara   46.0
# 2  tony         DU    Pune   45.2
# 1  mark        BHU  Mumbai   46.8
# 0   tom        JNU   Delhi   42.0

# %%
data.sort_values(by='MARKS',ascending=False)
# Out:
#    NAME UNIVERSITY    CITY  MARKS
# 1  mark        BHU  Mumbai   46.8
# 3  mark       SPPU  Satara   46.0
# 2  tony         DU    Pune   45.2
# 0   tom        JNU   Delhi   42.0
